# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (0.10.9)
# Requirement already satisfied: urllib3 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from chembl_webresource_client) (2.6.3)
# Requirement already satisfied: requests>=2.18.4 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from chembl_webresource_client) (2.32.5)
# Requirement already satisfied: requests-cache~=1.2 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from chembl_webresource_client) (1.3.1)
# Requirement already satisfied: easydict in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: attrs>=21.2 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (26.1.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (4.9.4)
# Requirement already satisfied: url-normalize>=2.0 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests-cache~=1.2->chembl_webresource_client) (2.2.1)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.14.0 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/students/mcubi/.conda/envs/bioinfo/lib/python3.10/site-packages (from requests>=2.18.4->chembl_webresource_client) (2026.2.25)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('acetylcholinesterase')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []    Drosophila melanogaster
# 1                []               Homo sapiens
# 2                []        Torpedo californica
# 3                []               Mus musculus
# 4                []          Rattus norvegicus
# 5                []   Electrophorus electricus
# 6                []                 Bos taurus
# 7                []          Anopheles gambiae
# 8                []             Bemisia tabaci
# 9                []  Leptinotarsa decemlineata
# 10               []     Nephotettix cincticeps
# 11               []              Gallus gallus
# 12               []                Danio rerio
# 13               []              Aedes aegypti
# 14               []               Homo sapiens
# 15               []            Musca domestica
# 16               []        Plutella xylostella
# 17               []            Musca domestica
# 18               []  Pediculus humanus capitis
# 19               []          Spodoptera litura
# 20               []      Laodelphax striatella
# 21               []        Schizaphis graminum
# 22               []               Homo sapiens
# 23               []          Rattus norvegicus
# 24               []     Caenorhabditis elegans
# 25               []             Equus caballus
# 26               []             Equus caballus
# 27               []     Canis lupus familiaris
# 28               []               Mus musculus
# 29               []          Rattus norvegicus
# 30               []               Homo sapiens
#
#                                             pref_name  score  \
# 0                                Acetylcholinesterase   18.0
# 1                                Acetylcholinesterase   16.0
# 2                                Acetylcholinesterase   16.0
# 3                                Acetylcholinesterase   16.0
# 4                                Acetylcholinesterase   16.0
# 5                                Acetylcholinesterase   16.0
# 6                                Acetylcholinesterase   16.0
# 7                                Acetylcholinesterase   16.0
# 8                                               AChE2   16.0
# 9                                Acetylcholinesterase   16.0
# 10               Ace-orthologous acetylcholinesterase   16.0
# 11                               Acetylcholinesterase   16.0
# 12                               Acetylcholinesterase   16.0
# 13                               Acetylcholinesterase   16.0
# 14                                       Protein CutA   16.0
# 15                               Acetylcholinesterase   15.0
# 16                               Acetylcholinesterase   15.0
# 17                               Acetylcholinesterase   15.0
# 18                               Acetylcholinesterase   15.0
# 19                               Acetylcholinesterase   15.0
# 20                               Acetylcholinesterase   15.0
# 21                               Acetylcholinesterase   15.0
# 22                       Cholinesterases; ACHE & BCHE   14.0
# 23  Acetylcholinesterase and butyrylcholinesterase...   14.0
# 24                             Acetylcholinesterase 1   14.0
# 25                              Butyrylcholinesterase   11.0
# 26                                     Cholinesterase   11.0
# 27                                     Cholinesterase   11.0
# 28                                     Cholinesterase   10.0
# 29                              Butyrylcholinesterase   10.0
# 30                                     Cholinesterase    5.0
#
#     species_group_flag target_chembl_id  \
# 0                False    CHEMBL2242744
# 1                False        CHEMBL220
# 2                False       CHEMBL4780
# 3                False       CHEMBL3198
# 4                False       CHEMBL3199
# 5                False       CHEMBL4078
# 6                False       CHEMBL4768
# 7                False    CHEMBL2046266
# 8                False    CHEMBL2366409
# 9                False    CHEMBL2366490
# 10               False    CHEMBL2366514
# 11               False    CHEMBL3227914
# 12               False    CHEMBL3308995
# 13               False    CHEMBL4295607
# 14               False    CHEMBL6067022
# 15               False       CHEMBL5752
# 16               False    CHEMBL2242729
# 17               False    CHEMBL2242743
# 18               False    CHEMBL2362988
# 19               False    CHEMBL2366422
# 20               False    CHEMBL2366446
# 21               False    CHEMBL2366511
# 22               False    CHEMBL2095233
# 23               False    CHEMBL2111475
# 24               False    CHEMBL3341583
# 25               False       CHEMBL5077
# 26               False       CHEMBL5763
# 27               False    CHEMBL4630814
# 28               False       CHEMBL2528
# 29               False       CHEMBL3403
# 30               False       CHEMBL1914
#
#                                     target_components        target_type  \
# 0   [{'accession': 'P07140', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'P22303', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P04058', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P21836', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'P37136', 'component_descriptio...     SINGLE PROTEIN
# 5   [{'accession': 'O42275', 'component_descriptio...     SINGLE PROTEIN
# 6   [{'accession': 'P23795', 'component_descriptio...     SINGLE PROTEIN
# 7   [{'accession': 'Q869C3', 'component_descriptio...     SINGLE PROTEIN
# 8   [{'accession': 'B3SST5', 'component_descriptio...     SINGLE PROTEIN
# 9   [{'accession': 'Q27677', 'component_descriptio...     SINGLE PROTEIN
# 10  [{'accession': 'Q9NJH6', 'component_descriptio...     SINGLE PROTEIN
# 11  [{'accession': 'P36196', 'component_descriptio...     SINGLE PROTEIN
# 12  [{'accession': 'Q9DDE3', 'component_descriptio...     SINGLE PROTEIN
# 13  [{'accession': 'Q6A2E2', 'component_descriptio...     SINGLE PROTEIN
# 14  [{'accession': 'O60888', 'component_descriptio...     SINGLE PROTEIN
# 15  [{'accession': 'Q95P20', 'component_descriptio...     SINGLE PROTEIN
# 16  [{'accession': 'Q8MZM0', 'component_descriptio...     SINGLE PROTEIN
# 17  [{'accession': 'Q7YWJ9', 'component_descriptio...     SINGLE PROTEIN
# 18  [{'accession': 'A2PZ98', 'component_descriptio...     SINGLE PROTEIN
# 19  [{'accession': 'C5IU80', 'component_descriptio...     SINGLE PROTEIN
# 20  [{'accession': 'K4JQ36', 'component_descriptio...     SINGLE PROTEIN
# 21  [{'accession': 'Q9BMJ1', 'component_descriptio...     SINGLE PROTEIN
# 22  [{'accession': 'P06276', 'component_descriptio...  SELECTIVITY GROUP
# 23  [{'accession': 'P37136', 'component_descriptio...  SELECTIVITY GROUP
# 24  [{'accession': 'P38433', 'component_descriptio...     SINGLE PROTEIN
# 25  [{'accession': 'Q9N1N9', 'component_descriptio...     SINGLE PROTEIN
# 26  [{'accession': 'P81908', 'component_descriptio...     SINGLE PROTEIN
# 27  [{'accession': 'P32750', 'component_descriptio...     SINGLE PROTEIN
# 28  [{'accession': 'Q03311', 'component_descriptio...     SINGLE PROTEIN
# 29  [{'accession': 'Q9JKC1', 'component_descriptio...     SINGLE PROTEIN
# 30  [{'accession': 'P06276', 'component_descriptio...     SINGLE PROTEIN
#
#     tax_id
# 0     7227
# 1     9606
# 2     7787
# 3    10090
# 4    10116
# 5     8005
# 6     9913
# 7     7165
# 8     7038
# 9     7539
# 10   94400
# 11    9031
# 12    7955
# 13    7159
# 14    9606
# 15    7370
# 16   51655
# 17    7370
# 18  121226
# 19   69820
# 20  195883
# 21   13262
# 22    9606
# 23   10116
# 24    6239
# 25    9796
# 26    9796
# 27    9615
# 28   10090
# 29   10116
# 30    9606

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3199'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1915  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1916  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1917  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1918  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1919  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           32049                                                 []
# 1           32050                                                 []
# 2           34486                                                 []
# 3           34487                                                 []
# 4           38116                                                 []
# ...           ...                                                ...
# 1915     24983030  [{'comments': None, 'relation': '=', 'result_f...
# 1916     24983031  [{'comments': None, 'relation': '=', 'result_f...
# 1917     24983032  [{'comments': None, 'relation': '=', 'result_f...
# 1918     25500533  [{'comments': None, 'relation': '=', 'result_f...
# 1919     25527622                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 1       CHEMBL642842  Effect on Acetylcholinesterase activity in rat...
# 2       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 3       CHEMBL642842  Effect on Acetylcholinesterase activity in rat...
# 4       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# ...              ...                                                ...
# 1915   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1916   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1917   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1918   CHEMBL5332046  Inhibition of rat cortex homogenate AChE prein...
# 1919   CHEMBL5339559  Inhibition of rat cortex homogenate AChE by El...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1915          B                    None                   None  BAO_0000190
# 1916          B                    None                   None  BAO_0000190
# 1917          B                    None                   None  BAO_0000190
# 1918          B                    None                   None  BAO_0000190
# 1919          B                    None                   None  BAO_0000190
#
#       ...    target_organism      target_pref_name target_tax_id text_value  \
# 0     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 2     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 3     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 4     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# ...   ...                ...                   ...           ...        ...
# 1915  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1916  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1917  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1918  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1919  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
#
#       toid  type units    uo_units upper_value  value
# 0     None   I50    mM  UO_0000065        None    0.1
# 1     None   I50    mM  UO_0000065        None   0.17
# 2     None   I50    mM  UO_0000065        None    0.2
# 3     None   I50    mM  UO_0000065        None    0.2
# 4     None   I50    mM  UO_0000065        None   0.26
# ...    ...   ...   ...         ...         ...    ...
# 1915  None  IC50    uM  UO_0000065        None  0.153
# 1916  None  IC50    uM  UO_0000065        None   1.53
# 1917  None  IC50    uM  UO_0000065        None  3.231
# 1918  None  IC50    uM  UO_0000065        None    1.2
# 1919  None  IC50    uM  UO_0000065        None   0.41
#
# [1920 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /tmp/ipykernel_2213623/3852201246.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 1915  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1916  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1917  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1918  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1919  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           32049                                                 []
# 1           32050                                                 []
# 2           34486                                                 []
# 3           34487                                                 []
# 4           38116                                                 []
# ...           ...                                                ...
# 1915     24983030  [{'comments': None, 'relation': '=', 'result_f...
# 1916     24983031  [{'comments': None, 'relation': '=', 'result_f...
# 1917     24983032  [{'comments': None, 'relation': '=', 'result_f...
# 1918     25500533  [{'comments': None, 'relation': '=', 'result_f...
# 1919     25527622                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 1       CHEMBL642842  Effect on Acetylcholinesterase activity in rat...
# 2       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 3       CHEMBL642842  Effect on Acetylcholinesterase activity in rat...
# 4       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# ...              ...                                                ...
# 1915   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1916   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1917   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1918   CHEMBL5332046  Inhibition of rat cortex homogenate AChE prein...
# 1919   CHEMBL5339559  Inhibition of rat cortex homogenate AChE by El...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 3             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1915          B                    None                   None  BAO_0000190
# 1916          B                    None                   None  BAO_0000190
# 1917          B                    None                   None  BAO_0000190
# 1918          B                    None                   None  BAO_0000190
# 1919          B                    None                   None  BAO_0000190
#
#       ...    target_organism      target_pref_name target_tax_id text_value  \
# 0     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 2     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 3     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 4     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# ...   ...                ...                   ...           ...        ...
# 1915  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1916  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1917  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1918  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1919  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
#
#       toid  type units    uo_units upper_value  value
# 0     None   I50    mM  UO_0000065        None    0.1
# 1     None   I50    mM  UO_0000065        None   0.17
# 2     None   I50    mM  UO_0000065        None    0.2
# 3     None   I50    mM  UO_0000065        None    0.2
# 4     None   I50    mM  UO_0000065        None   0.26
# ...    ...   ...   ...         ...         ...    ...
# 1915  None  IC50    uM  UO_0000065        None  0.153
# 1916  None  IC50    uM  UO_0000065        None   1.53
# 1917  None  IC50    uM  UO_0000065        None  3.231
# 1918  None  IC50    uM  UO_0000065        None    1.2
# 1919  None  IC50    uM  UO_0000065        None   0.41
#
# [1847 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 1571

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 2                                                  None             None
# 4                                                  None             None
# 6                                                  None             None
# 8                                                  None             None
# ...                                                 ...              ...
# 1912  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1913  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1916  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1917  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1919  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# 0           32049                                                 []
# 2           34486                                                 []
# 4           38116                                                 []
# 6           41591                                                 []
# 8           42915                                                 []
# ...           ...                                                ...
# 1912     24963337  [{'comments': None, 'relation': '=', 'result_f...
# 1913     24963338  [{'comments': None, 'relation': '=', 'result_f...
# 1916     24983031  [{'comments': None, 'relation': '=', 'result_f...
# 1917     24983032  [{'comments': None, 'relation': '=', 'result_f...
# 1919     25527622                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 2       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 4       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 6       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# 8       CHEMBL642843  Effect on Acetylcholinesterase activity in rat...
# ...              ...                                                ...
# 1912   CHEMBL5216421  Inhibition of Sprague-Dawley rat cortex AChE u...
# 1913   CHEMBL5216421  Inhibition of Sprague-Dawley rat cortex AChE u...
# 1916   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1917   CHEMBL5226654  Inhibition of rat cortex AChE using acetylthio...
# 1919   CHEMBL5339559  Inhibition of rat cortex homogenate AChE by El...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 2             B                    None                   None  BAO_0000190
# 4             B                    None                   None  BAO_0000190
# 6             B                    None                   None  BAO_0000190
# 8             B                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 1912          B                    None                   None  BAO_0000190
# 1913          B                    None                   None  BAO_0000190
# 1916          B                    None                   None  BAO_0000190
# 1917          B                    None                   None  BAO_0000190
# 1919          B                    None                   None  BAO_0000190
#
#       ...    target_organism      target_pref_name target_tax_id text_value  \
# 0     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 2     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 4     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 6     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 8     ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# ...   ...                ...                   ...           ...        ...
# 1912  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1913  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1916  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1917  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
# 1919  ...  Rattus norvegicus  Acetylcholinesterase         10116       None
#
#       toid  type units    uo_units upper_value  value
# 0     None   I50    mM  UO_0000065        None    0.1
# 2     None   I50    mM  UO_0000065        None    0.2
# 4     None   I50    mM  UO_0000065        None   0.26
# 6     None   I50    mM  UO_0000065        None   0.06
# 8     None   I50    mM  UO_0000065        None    0.2
# ...    ...   ...   ...         ...         ...    ...
# 1912  None  IC50    uM  UO_0000065        None   6.97
# 1913  None  IC50    uM  UO_0000065        None   4.11
# 1916  None  IC50    uM  UO_0000065        None   1.53
# 1917  None  IC50    uM  UO_0000065        None  3.231
# 1919  None  IC50    uM  UO_0000065        None   0.41
#
# [1571 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL15886            CC[N+](C)(CC)CC(=O)CCN1C(=O)CCC1=O.[I-]
# 2          CHEMBL556129                         C[n+]1ccccc1CCC(O)CCl.[I-]
# 4           CHEMBL15795                             C[N+](C)(C)CCCCl.[Br-]
# 6          CHEMBL276539                          BrCCCCCC[n+]1ccccc1.[Br-]
# 8          CHEMBL278956                       CC[N+](C)(CC)CCc1ccncc1.[I-]
# ...                 ...                                                ...
# 1912      CHEMBL5219903  CN1CCN(C(=O)Oc2ccc(/C=C/c3cc(OC(=O)N4CCN(C)CC4...
# 1913      CHEMBL5220947  O=C(Oc1ccc(/C=C/c2cc(OC(=O)N3CCN(Cc4ccccc4)CC3...
# 1916      CHEMBL5271210  O=C1[C@@H]2Cc3c([nH]c4ccccc34)[C@@H](c3ccc4c(c...
# 1917      CHEMBL5275356  COc1ccc([C@@H]2c3[nH]c4ccccc4c3C[C@H]3C(=O)N(C...
# 1919      CHEMBL5422194  CCN(CCCCCCOc1ccc(/C=C/C(=O)c2c(O)cc(OC)c(O)c2O...
#
#      standard_value
# 0          100000.0
# 2          200000.0
# 4          260000.0
# 6           60000.0
# 8          200000.0
# ...             ...
# 1912         6970.0
# 1913         4110.0
# 1916         1530.0
# 1917         3231.0
# 1919          410.0
#
# [1571 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL15886            CC[N+](C)(CC)CC(=O)CCN1C(=O)CCC1=O.[I-]
# 1          CHEMBL556129                         C[n+]1ccccc1CCC(O)CCl.[I-]
# 2           CHEMBL15795                             C[N+](C)(C)CCCCl.[Br-]
# 3          CHEMBL276539                          BrCCCCCC[n+]1ccccc1.[Br-]
# 4          CHEMBL278956                       CC[N+](C)(CC)CCc1ccncc1.[I-]
# ...                 ...                                                ...
# 1566      CHEMBL5219903  CN1CCN(C(=O)Oc2ccc(/C=C/c3cc(OC(=O)N4CCN(C)CC4...
# 1567      CHEMBL5220947  O=C(Oc1ccc(/C=C/c2cc(OC(=O)N3CCN(Cc4ccccc4)CC3...
# 1568      CHEMBL5271210  O=C1[C@@H]2Cc3c([nH]c4ccccc34)[C@@H](c3ccc4c(c...
# 1569      CHEMBL5275356  COc1ccc([C@@H]2c3[nH]c4ccccc4c3C[C@H]3C(=O)N(C...
# 1570      CHEMBL5422194  CCN(CCCCCCOc1ccc(/C=C/C(=O)c2c(O)cc(OC)c(O)c2O...
#
#       standard_value         class
# 0           100000.0      inactive
# 1           200000.0      inactive
# 2           260000.0      inactive
# 3            60000.0      inactive
# 4           200000.0      inactive
# ...              ...           ...
# 1566          6970.0  intermediate
# 1567          4110.0  intermediate
# 1568          1530.0  intermediate
# 1569          3231.0  intermediate
# 1570           410.0        active
#
# [1571 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip acetylcholinesterase_0[1-3]*.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 82%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 83%)

# %%
! ls -l
# Out:
# total 17780
# -rw-r--r-- 1 mcubi students 1013813 Mar 23 18:29 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 mcubi students  113254 Mar 23 18:29 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 mcubi students  127407 Mar 23 18:29 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 mcubi students  655414 Mar 23 18:14 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# -rw-r--r-- 1 mcubi students  489152 Mar 23 18:14 acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv
# -rw-r--r-- 1 mcubi students 8363909 Mar 23 18:14 acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# -rw-r--r-- 1 mcubi students 6323895 Mar 23 18:14 acetylcholinesterase_07_bioactivity_data_2class_pIC50_pubchem_fp.csv
# -rw-r--r-- 1 mcubi students  134859 Mar 23 18:32 acetylcholinesterase.zip
# -rw-r--r-- 1 mcubi students  104677 Mar 23 18:30 CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb
# -rw-r--r-- 1 mcubi students  313244 Mar 23 18:14 CDD_ML_Part_2_Acetylcholinesterase_Exploratory_Data_Analysis.ipynb
# -rw-r--r-- 1 mcubi students  208719 Mar 23 18:14 CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb
# -rw-r--r-- 1 mcubi students  100076 Mar 23 18:14 CDD_ML_Part_4_Acetylcholinesterase_Regression_Random_Forest.ipynb
# -rw-r--r-- 1 mcubi students  230778 Mar 23 18:14 CDD_ML_Part_5_Acetylcholinesterase_Compare_Regressors.ipynb
# -rw-r--r-- 1 mcubi students      29 Mar 23 18:14 README.md

# %% [markdown]
# ---
